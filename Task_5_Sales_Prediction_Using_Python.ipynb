# %% [markdown]
# # SALES PREDICTION USING PYTHON
#
# ### Introduction
#
# Sales prediction is the process of forecasting the quantity of a product that consumers will purchase depending on variables like the advertising budget, the target market, and the platform you are using.
#
#
# A company that sells goods and services usually needs a data scientist to forecast future sales for each action they take to control the expense of product advertising. So let's get started on the Python machine learning sales prediction job.

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
# Read  Data
df = pd.read_csv('Advertising.csv')
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.regplot(x='TV',y='Sales',data=df)
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
plt.figure(figsize=(8,6))
sns.regplot(x='Newspaper',y='Sales',data=df)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
plt.figure(figsize=(8,6))
sns.regplot(x='Radio',y='Sales',data=df)
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sns.pairplot(df)

# %%
sns.pairplot(data = df , hue = 'Sales')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
x=df[ ['Unnamed: 0','TV', 'Radio', 'Newspaper']]
y=df[[ 'Sales' ]]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import OrdinalEncoder
scaler = StandardScaler()
x= scaler.fit_transform(x)

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=.2,shuffle=True)

# %%
model = LinearRegression()

model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score
print(f''' The train accuracy : {r2_score(y_train,model.predict(x_train))}
The test accuracy : {r2_score(y_test , y_pred)}''')
# Out:
#  The train accuracy : 0.9040826362672026
# The test accuracy : 0.8579022571396452

# %%
random_forest = RandomForestRegressor(n_estimators=100)
random_forest.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
random_f_pred = random_forest.predict(x_test)

# %%
r2_score(y_test,random_f_pred)
# Out:
# 0.9733260436525875

# %% [markdown]
# ### Model is good fit on Train dataset & Performance of model on Test data is also good fit

# %% [markdown]
# ### CONCLUSION

# %% [markdown]
# We can say that we comprehended the modeling process and statistical technique for the sales forecast dataset.
# With a strong fit, we anticipate 97.33% accuracy on the train dataset and 85% accuracy on the test dataset.
# Compared to radio and newspapers, TV marketing has the biggest effect on sales.
# When it comes to sales prediction, all of the linear regression's assumptions are accurate.
